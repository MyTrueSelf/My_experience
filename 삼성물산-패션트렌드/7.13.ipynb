# %%
import os
import pandas as pd
import numpy as np
import xlrd, xlwt
os.listdir(r"C:\Users\74857\Desktop\과제\삼성물산")
# Out:
# ['(Springer Texts in Statistics) Robert H. Shumway, David S. Stoffer (auth.)-Time Series Analysis and Its Applications_ With R Examples-Springer International Publishing (2017).pdf',
#  'Data exploration.ipynb',
#  'Data exploration.zip',
#  'SLP.pdf',
#  'SLP_CH5.pdf',
#  'temp.txt',
#  '~$링한 자료의 정규화.docx',
#  '~$삼성물산_빅데이터분석_요구사항정의_V0.9.pptx',
#  '~$상품&브랜드키워드_20180531.xlsx',
#  '~$소재정보_17SSFW.xlsx',
#  '내가 해뒀던것',
#  '다 분류하질 못했다.R',
#  '삼성물산_빅데이터분석_요구사항정의_V0.9.pptx',
#  '상품&브랜드키워드_20180531.xlsx',
#  '소재.csv',
#  '소재.xlsx',
#  '소재정보_17SSFW.xlsx',
#  '의류 소재 분류기준 .pptx',
#  '인기검색어.csv',
#  '인기검색어.txt',
#  '인기검색어.xlsx',
#  '인기검색어2.csv',
#  '한글 추출 정리',
#  '한글만.csv',
#  '회의록']

# %%
PATH = r"C:\Users\74857\Desktop\과제\삼성물산\\"
ANSWER = "소재.csv"
TRAIN = "소재기준.csv"

# %%
with open(PATH + "temp.txt", "r") as f:
    temp = pd.read_table(f, header = None)

# %%
tt = [i[0] for i in list(temp.values)]

# %%
tt
# Out:
# ['합성가죽 천연가죽 소가죽 ',
#  '모 나일론 폴리에스터 ',
#  '겉감 나일론 폴리에스테르 충전재 거위솜털 거위깃털 ',
#  '겉감 폴리에스테르 ',
#  '겉감 폴리에스테르 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 ',
#  '겉감 폴리에스테르 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 나일론 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '같감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 스판 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 스판덱스 ',
#  '겉감 폴리에스테르 안감 폴리에스테르 ',
#  '겉감 폴리에스테르 ',
#  '겉감 폴리에스테르 안감 폴리에스테르 ',
#  '겉감 폴리에스테르 안감 폴리에스테르 충전재 폴리에스테르 ',
#  '겉감 폴리에스테르 ',
#  '겉감 나일론 폴리에스테르 폴리우레탄 ',
#  '겉감 폴리에스테르 ',
#  '겉감 면 폴리에스테르 ',
#  '겉감 면 폴리에스테르 ',
# ...

# %%
set([word for i in tt for word in i.split()])
# Out:
# {'바구니',
#  '창갈이',
#  '차이나구스솜털',
#  '인조가죽',
#  '사이즈기준실측',
#  '스와브스키',
#  '같김',
#  '아라미드',
#  '기법을',
#  '부클사',
#  '리브부분',
#  '감',
#  '관련법',
#  '착용전',
#  '햄스울',
#  '다크',
#  '엣스터',
#  '니트풀오버',
#  '수저',
#  '임지',
#  '갑피',
#  '케이프',
#  '나일렁',
#  '탭',
#  '퍼포먼스',
#  '스카프',
#  '거싯',
#  '데임',
#  '이루어질',
#  '코펠',
#  '멜란지',
#  '합성섬유',
#  '모달',
#  '써지컬침',
#  '피',
#  '공백처리',
#  '달라질',
#  '던킨엠보',
#  '폴리에',
#  '오리털솜터',
#  '압성고무',
#  '가을',
#  '미제공으로',
#  '다이평직',
#  '최소다운',
#  '핸들',
#  '마스트로또',
#  '강화',
#  '라일락',
#  '신슐레이트',
#  '합성가죽중창',
#  '사용해',
#  '장식제외',
#  '열가소서우레탄수지',
#  '겉김',
#  '크로크엠보',
#  '파일런',
#  '세부사항참조',
#  '고강도',
#  '원피스겉감',
#  '퐆리에스터',
#  '스플릿',
#  '아웃솔부틸',
#  '촉사용',
#  '안',
#  '헤드',
#  '다운깃털',
#  '그레이모',
#  '토끼',
#  '셀룰로오스계섬유',
#  '핏',
#  '키드모헤어',
#  '측면',
#  '만들었습니다',
#  '미감별모',
#  '메리노',
#  '리우레탄',
#  '상세이미지',
#  '폴리에틸렌폼',
#  '비비드그린',
#  '아쿠아벤트',
#  '코오롱인더스트리',
#  '부팬츠',
#  '램',
#  '배색털너구리털',
#  '콤비원단',
#  '브레이디드',
#  '로즈골드사틴',
#  '라벨참조',
#  '페이지',
#  '후',
#  '제품이',
#  '폴리에루탄',
# ...

# %%
import codecs

with open(PATH + ANSWER) as f:
    fileObj = codecs.open( f, "r", "utf-8" )

u = fileObj.readlines()

for i in u:
    print(i)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-676ba8ef0936> in <module>()
#       2
#       3 with open(PATH + ANSWER) as f:
# ----> 4     fileObj = codecs.open( f, "r", "utf-8" )
#       5 u = fileObj.readlines()
#       6
#
# C:\Anaconda3\lib\codecs.py in open(filename, mode, encoding, errors, buffering)
#     895         # Force opening of the file in binary mode
#     896         mode = mode + 'b'
# --> 897     file = builtins.open(filename, mode, buffering)
#     898     if encoding is None:
#     899         return file
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
with open(PATH + TRAIN, "r") as f:
    train = pd.read_csv(f,  engine = 'python')

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-3b77fa18a747> in <module>()
# ----> 1 train.head()
#
# NameError: name 'train' is not defined
